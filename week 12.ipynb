# %%
import pandas as pd

# %%
import numpy as np

# %%
M = pd.read_csv('movies.csv', index_col='Name')

# %%
M.head()
# Out:
#                     American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                     4                                    NaN
# Aditya Dharmasagar                5                                    NaN
# Adrian Cavallaris               NaN                                      4
# Ahmed Muheebuddin                 5                                    NaN
# Aishwarya reddy                 NaN                                      3
#
#                     Guardians of the Galaxy  The Lego Movie  The Hobbit  \
# Name
# Aarti Jaiswal                           NaN             NaN           4
# Aditya Dharmasagar                      NaN               4           5
# Adrian Cavallaris                         3             NaN           4
# Ahmed Muheebuddin                         4             NaN           3
# Aishwarya reddy                           4               3           4
#
# ...

# %%
M.shape
# Out:
# (76, 16)

# %%
M
# Out:
#                              American Sniper  \
# Name
# Aarti Jaiswal                       4.000000
# Aditya Dharmasagar                  5.000000
# Adrian Cavallaris                        NaN
# Ahmed Muheebuddin                   5.000000
# Aishwarya reddy                          NaN
# Akhilesh                                 NaN
# Andrew Webb                         4.000000
# Anirudh                             3.000000
# Anirudh Thota                            NaN
# anurag                              4.000000
# Anusha Putta                             NaN
# Arun Vedere                         4.000000
# Ashutosh Sureka                     5.000000
# Aswini kumar                        4.000000
# azam                                4.000000
# Benjamin Baysinger                  5.000000
# Bhuvana Posina                      5.000000
# Bradley Brubaker                         NaN
# Brant Mullinix                           NaN
# Charlie                                  NaN
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
pearson(M['The Fault in Our Stars'],M['Malificent'] )
# Out:
# 0.39873118100855826

# %%
pearson(M['The Fault in Our Stars'], M['American Sniper'])
# Out:
# -0.0027509195890370419

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:10]
# Out:
# [('Malificent', 0.39873118100855826),
#  ('Godzilla', 0.27910171761590286),
#  ('How to Train your Dragon 2', 0.22514201090703723),
#  ('Gone Girl', 0.14705909007675133),
#  ('Interstellar', 0.12286970596222707),
#  ('Unbroken', 0.11298392969275164),
#  ('Guardians of the Galaxy', 0.090874959467711777),
#  ('Divergent', 0.071129882767397401),
#  ('The Hunger Games: Mockingjay - Part 1', 0.053533966431183633),
#  ('The Lego Movie', 0.051121037070687873)]

# %%
anti_recs = get_recs('The Fault in Our Stars', M, 8551)

# %%
anti_recs[-10:]
# Out:
# [('Unbroken', 0.11298392969275164),
#  ('Guardians of the Galaxy', 0.090874959467711777),
#  ('Divergent', 0.071129882767397401),
#  ('The Hunger Games: Mockingjay - Part 1', 0.053533966431183633),
#  ('The Lego Movie', 0.051121037070687873),
#  ('Transformers', 0.042958080479063222),
#  ('The Hobbit', 0.038628454138809519),
#  ('American Sniper', -0.0027509195890370419),
#  ('300: Rise of an Empire', -0.053185970909404523),
#  ('Big Hero 6', -0.18665349454812516)]

# %% [markdown]
# # 1Ans: Maleficient is the most similar movie to "The fault in our stars" as per the above outputs that we have received.

# %%
recs = get_recs('Malificent', M, 10)

# %%
recs[:1]
# Out:
# [('The Fault in Our Stars', 0.39873118100855826)]

# %%
ratings = M.ix['Sara Collins'].dropna()

# %%
ratings.sort(ascending=False)
fav_movie = ratings.index[0]
# Out:
# C:\Users\shru.shru-PC\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   if __name__ == '__main__':

# %%
fav_movie = ratings.index[0]

# %%
recs = get_recs('Gone Girl', M, 10)

# %%
recs[:10]
# Out:
# [('The Fault in Our Stars', 0.14705909007675133),
#  ('The Lego Movie', 0.1233839307397927),
#  ('How to Train your Dragon 2', 0.11123592989213005),
#  ('Godzilla', 0.095217741548246887),
#  ('300: Rise of an Empire', 0.087816187972314844),
#  ('Unbroken', 0.070310485168203027),
#  ('Interstellar', 0.054486961644112257),
#  ('American Sniper', 0.021549485282159685),
#  ('Divergent', 0.014708426410739026),
#  ('Transformers', 0.0058415580617180805)]

# %% [markdown]
# # 2Ans: By using the get recs function and passing my favourite movie as "Gone Girl" and requesting for 10 recommendations as per the review given by my classmates. Given below are my 10 recommendations:
# ('The Fault in Our Stars', 0.14705909007675133),
#  ('The Lego Movie', 0.1233839307397927),
#  ('How to Train your Dragon 2', 0.11123592989213005),
#  ('Godzilla', 0.095217741548246887),
#  ('300: Rise of an Empire', 0.087816187972314844),
#  ('Unbroken', 0.070310485168203027),
#  ('Interstellar', 0.054486961644112257),
#  ('American Sniper', 0.021549485282159685),
#  ('Divergent', 0.014708426410739026),
#  ('Transformers', 0.0058415580617180805)

# %% [markdown]
# # 3Ans: According to the recommendations that I've received from my classmates reviews, I would rate the movie(s) that I haven't seen as per the highest positive coefficient number between my favourite movie and the movie that I haven't watched.
